# %%
"""
Nome: Verifica-idade
Desrição: Este programa pergunnta a idade e retorna se a pessoa é adulta ou não
Autor: Sérgio Fernandes
Versão:0.0.1

"""
# Out:
# '\nNome: Verifica-idade\nDesrição: Este programa pergunnta a idade e retorna se a pessoa é adulta ou não\nAutor: Sérgio Fernandes\nVersão:0.0.1\n\n'

# %%
#Alocação de Memória
Idade=0

# %%
#
